# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, fbeta_score, plot_confusion_matrix
from sklearn.ensemble import RandomForestRegressor

# %%
import pandas as pd

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score

# %%
from sklearn.decomposition import PCA

# %%
from operator import itemgetter

# %%
from sklearn.svm import SVR

# %%
from sklearn.feature_selection import RFE

# %% [markdown]
# ## Reading the data and taking a look inside

# %%
train_data, test_data = pd.read_csv('regression_train.csv'), pd.read_csv('regression_test.csv')
data = pd.concat([test_data, train_data], ignore_index=True)
data.sample(10)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 471           70       RM         34.0     4571   Pave  Grvl      Reg
# 846           20       RL         65.0     8450   Pave   NaN      Reg
# 921           20       RL         60.0     7200   Pave   NaN      Reg
# 66           190       RM         50.0     6000   Pave   NaN      Reg
# 335           20       RL          NaN     9000   Pave   NaN      Reg
# 85            20       RL         75.0    11310   Pave   NaN      Reg
# 404           50       RL         80.0     9600   Pave   NaN      Reg
# 1122          50       RL         60.0    10410   Pave  Grvl      Reg
# 1454          80       RL          NaN     8530   Pave   NaN      IR1
# 696           20       RL         93.0     9382   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 471          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   int64
#  1   MSZoning       1459 non-null   object
#  2   LotFrontage    1200 non-null   float64
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1459 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Removing and filling Nan-values

# %%
data.isna().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1368
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %% [markdown]
# As we can see above there are some columns that mostly contain Nan-values, for example Alley, Fireplace and Fence. In the next step we will remove them and fill those that only have some Nan-values with the most common value for that column.

# %% [markdown]
# #### Removing columns with more than 100 Nan-values

# %%
columns = data.columns
nan_columns = []
for i, val in enumerate(data.isna().sum()):
    if val > 100:
        nan_columns.append(columns[i])
data = data.drop(nan_columns, axis=1)

# %% [markdown]
# #### Filling the remaning Nan-values with the most common value for that column

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
result = imputer.fit_transform(data)
new_data = pd.DataFrame(result, columns=data.columns)

new_data = new_data.astype(data.dtypes)
new_data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# Now we have no Nan-values left in our data.

# %% [markdown]
# ## Encoding string variables

# %%
from category_encoders.binary import BinaryEncoder
encoder = BinaryEncoder(return_df=True)
data = encoder.fit_transform(new_data)
# Out:
# C:\Users\sarak\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %% [markdown]
# All the categorical columns were encoded, and now we have 177 columns insted of 74.

# %% [markdown]
# ## Trying out diffrerent models

# %%
data.sample(15)
# Out:
#       MSSubClass  MSZoning_0  MSZoning_1  MSZoning_2  MSZoning_3  LotArea  \
# 742          120           0           0           0           1    10846
# 788           50           0           0           1           0     8800
# 250           20           0           0           0           1     7162
# 1386          20           0           0           0           1     6627
# 1032          30           0           0           0           1    13907
# 1265         160           0           0           1           1     3230
# 1142          20           0           0           0           1    10530
# 1381          20           0           0           0           1    11600
# 274           60           0           0           0           1    11700
# 1013          60           0           0           0           1    10364
# 1134          45           0           0           1           0     7449
# 434          120           0           0           0           1     4928
# ...

# %%
def prepare_data_and_fit_model(data, model, n_components=176, feature_selection=False, log_transform=False):
    X = data.copy()
    y = X.pop('SalePrice')
    
    if log_transform:
        pass
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2, shuffle=True)
    
    if feature_selection:
        estimator = SVR(kernel="linear").fit(X_train, y_train)
        n_features_to_remove = 5
        selection = [(i, score) for i, score in enumerate(estimator.coef_[0])]
        selection.sort(key=itemgetter(1))
        columns = list(X.columns)
        for col in selection[:n_features_to_remove]:
            del columns[col[0]]
        X_train = X_train[columns]
        X_test = X_test[columns]
    
    if model == 'SVR':
        model = SVR(kernel="linear").fit(X_train, y_train)
        
    elif model == 'RF':
        model = RandomForestRegressor()
    
    
    
    predictions = model.predict(X_test)
    accuracy = model.score(X_test, y_test)
    mse = mean_squared_error(y_test, predictions)
    mape = mean_absolute_percentage_error(y_test, predictions)
    r2 = r2_score(y_test, predictions)
    correlation_matrix = pd.DataFrame(X).corr()
    
    result = {'X': X,
             'y': y,
             'x_train': X_train,
             'x_test': X_test, 
             'y_train': y_train,
             'y_test': y_test,
             'model': model,
             'predictions': predictions,
             'accuracy': accuracy, 
             'mse': mse,
             'mape': mape, 
             'r2': r2,
             'correlation_matrix': correlation_matrix
            }
    
    return result

# %%
X = data.copy()
y = X.pop('SalePrice')

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2, shuffle=True)

model = SVR(kernel="linear").fit(X_train, y_train)
n_features_to_remove = X.shape[1]-5
selection = [(i, score) for i, score in enumerate(model.coef_[0])]
selection.sort(key=itemgetter(1))
columns = list(X.columns)
for col in selection[:5]:
    del columns[col[0]]
X_train = X_train[columns]
X_test = X_test[columns]
# Out:
# 126
# BedroomAbvGr
# 89
# BsmtExposure_0
# 110
# HeatingQC_2
# 0
# MSSubClass
# 81
# Foundation_2

# %% [markdown]
# ## Correlations with all features

# %%
with plt.style.context('ggplot'):
    matfig = plt.figure(figsize=(10,10))
    plt.matshow(data.corr(), fignum=matfig.number)
    plt.grid(False)
    plt.title('Correlations')
    plt.colorbar(fraction = 0.045)

# %% [markdown]
# ## Support Vector Machine

# %%
result = prepare_data_and_fit_model(data, 'SVR')
print(f'Accuracy: {result["accuracy"]}, MSE: {result["mse"]}, MAPE: {result["mape"]}, R2: {result["r2"]}')
# Out:
# Accuracy: 0.7913523088725587, MSE: 1566973414.8588462, MAPE: 0.12017501375921746, R2: 0.7913523088725587

# %% [markdown]
# #### With feature selection

# %%
result = prepare_data_and_fit_model(data, 'SVR', feature_selection=True)
print(f'Accuracy: {result["accuracy"]}, MSE: {result["mse"]}, MAPE: {result["mape"]}, R2: {result["r2"]}')
# Out:
# Accuracy: 0.7847734987594144, MSE: 1616381201.2234943, MAPE: 0.12547253268794675, R2: 0.7847734987594144

# %% [markdown]
# ## Random Forest

# %%
result = prepare_data_and_fit_model(data, 'RF')
print(f'Accuracy: {result["accuracy"]}, MSE: {result["mse"]}, MAPE: {result["mape"]}, R2: {result["r2"]}')
# Out:
# Accuracy: 0.87187801173217, MSE: 962214095.8747572, MAPE: 0.09721475299876013, R2: 0.87187801173217

# %% [markdown]
# #### With feature selection

# %%
result = prepare_data_and_fit_model(data, 'RF', feature_selection=True)
print(f'Accuracy: {result["accuracy"]}, MSE: {result["mse"]}, MAPE: {result["mape"]}, R2: {result["r2"]}')
# Out:
# C:\Users\sarak\anaconda3\lib\site-packages\sklearn\base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - BedroomAbvGr
# - BsmtExposure_0
# - Foundation_3
# - HeatingQC_3
# - MSSubClass
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-288-941d3f8e7e56> in <module>
# ----> 1 result = prepare_data_and_fit_model(data, 'RF', feature_selection=True)
#       2 print(f'Accuracy: {result["accuracy"]}, MSE: {result["mse"]}, MAPE: {result["mape"]}, R2: {result["r2"]}')
#
# <ipython-input-286-004ddd77e79a> in prepare_data_and_fit_model(data, model, n_components, feature_selection, log_transform)
#      27
#      28
# ---> 29     predictions = model.predict(X_test)
# ...

# %% [markdown]
# ## Correlations with feature selection
